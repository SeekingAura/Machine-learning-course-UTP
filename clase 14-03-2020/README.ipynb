# %% [markdown]
# # Distribución predictiva
# La medida de los datos me indica los datos que son mas probables partiendo de la media y usando la varianza
#
# ## Aproximación de la evidencia (I)
# * Si no se conocen $\alpha$ y $\beta$ cómo se pueden estimar a partir del conjunto de entrenamiento. Estos valores deben ser estimados
#
# Alpha varianza de los datos w (parametros) como priori
#
# Betha es el ruido de los datos
#
# * En un tratamiento bayesiano general, se ponene priors sobre $\alpha$ y $\beta$
#
# * El algoritmo vendria a ser como un bayes empirico y es iterativo
#
# ## Aproximaci´pn de la evidencia (II)
# * La evidencia está dada como
#
# $E(w)$ -> Error cuadratico medio
#
#
# ## Aproximación de la evidencia
#
# $m_N$ la media del posteriori con N datos de entrenamiento
#
# $E(m_N)$
#
# $E(m_N)$ matriz gradiente es igual a la matriz A
#
# ## Aproximación de la evidencia (IV)
# * Par acalcular la integral sal cauclar entrega un exponencial con el valor de error cuadratico medio y la matrix A
#
# * La evidencia algoritmica debe ser maximizada
#
# # Maximización con respecto a $\alpha$ (I)
# * Recordemos que el determinante de una matriz cuadrada **P** se puede calcular como la productoria de los valores propios, es decir tengo
#
#
# ## Maximización con respecto a $\alpha$ (II)
# * Usando el reusltado de la derivada de
#
# ## Maximización con respecto a $\beta$ (I)
# * Los valores propios
#
# ## Maximización con respecto a $\beta$ (II)
# * Con el valor de la derivada se continua calculando un posteriori
#
# # Proceso de maximización
#
# ## Verosimilitud tipo II
#
# Inicialización
#
# Obtener los valores priory donde $m_0$ es
#
# $m_0=0 \beta S_{N} \phi^{\top}t$ -> Donde M es de acuerod a la cantidad de valores de $m_N$
#
# $S_0=\alpha I \in \mathbb{R}^{MxM}$
#
# $\{\bar{\lambda}_{i}\}=eig(\phi ^{\top}\phi)$
#
# $tol \beta, tol \alpha ; \beta =1, \alpha =1$
#
# mientras $error \beta \geq tol\beta \ AND\ error \alpha > tol\alpha$:
#
# Calcule $\lambda _{i}=\beta \bar{\lambda} _{i}$
#
# Calculamos $\alpha _{i}=(\frac{\gamma}{m^{\top}_{i} m_{i}} )$
#
# Calculamos $\beta _{i}=(\frac{1}{N-\gamma}||\textbf{t}-\phi m_{i}||^{2} _{2})^{-1}$
#
# Calculamos $m_{i+1}, S_{i+1}$
#
# Calcular error $\beta, error \alpha$
