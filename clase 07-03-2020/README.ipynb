# %% [markdown]
# # Analisis al sistema
# La cantidad de datos vienen X y las "ecucaciones" vienen del valor $\mu$
#
# Los valores propios en un sistema me determinan o establecen el comportamiento de la regresión en el sistema, si hay valore spropios con valor 0 presenta que la matriz relacioanda no sea invertible genernado la posibilidad de sobre-ajustado, los valores propios solo aplica en valores de norma 2 o superior
#
# la regulación en un modelo es modificando los valroes de ajuste, la cual regulizariza o suaviza (hace rque sea casi una recta) con esto se trata de evitar los sobre ajustes
#
#
# # Definiciones
#
# ## Regresión bayesiana Lineal
# Ayuda a hacer regresión con ajustes
#
# Teorema de bayes
#
# $\LARGE p(a,b)=p(a|b)p(b)=p(b|a)p(a)$
#
# Verosimilitud
#
# $\LARGE p(a|b)=\frac{p(b|a)p(a)}{p(b)}$
#
# $p(a|b)$ -> Posterior
#
# $p(b)$ -> Prior
#
# $p(b)$ -> Evidencia
#
# $p(b|a)$ -> Verosimilitud likehood bondad de ajuste.
#
# * Una alternativa a la regularización es el tratamiento Bayesiano.
# * La verosimilitud del modelo está dado como
#
# $\huge p(\textbf{t}|\textbf{w},\beta )=\eta (\textbf{t}|\phi \textbf{w}, \beta ^{-1} \textbf{l})$
#
# Se busca maximizar la probabilidad
#
# * Lo que se hizo en máxima verosimilitud fue realizar una estimación puntual para **w**, que denotamos como $\textbf{w}_{ML}$
#
# w ya no es una variable deterministica determinada de manera puntual si no que va ser aleatoria
#
# * En estimación Bayesiana, asumidos un prior para **w** y calculamos la probabilidad a posteriori de **w** dados los datos **t**
# * El posterior sobre **w** se usa para hace rpredicciones
#
# Se busca llegar a la probabilidad de **w** ya que como nuestor modelo de verosimilud busca aumentar sus probabilidades por que w ahroa es una probabilidad conr especto a lo anterior
#
# * Asumiendo que el prior es Gaussiano, el posterior es igualmente gaussiano
# * supongamos que $p(\textbf{w})=\eta (\textbf{w}|\textbf{m}_0 , \textbf{s}_0)$
# * Usando propiedades de la gaussiana, se puede obtener que
#
# $\large \textbf{m}_N =\textbf{S}_N (\textbf{S} _{0} ^{-1} \textbf{m}_0 + \beta \phi^{\top}\textbf{t})$
#
# $S_{N}^{-1}$ -> es la covarianza de los N datos y este es establecido o encotnrado gracias a que tiene la campana de gauss utilizando la media y la varianza
# $m_N$ -> Es la media de los datos, recordar que es el posteiror
#
# De acuerdo al conocimiento prior (conocimiento anterior) tiene un efecto o requeirimiento de que el conocimiento posteiror tenga ciertas condiciones.
#
# La probabilidades combinadas de las gausianas sigen siendo gausianas
#
# E
#
# # La Prior más simple
# * Un prior más sencillo sigue siendo de la forma $p(\textbf{w}=\eta (\textbf{w}|\textbf{0},\alpha ^{-1} \textbf{l}))$
#
# $\alpha ^{-1}$ ->Covarianza esferica
#
# * El posterior está dado como
# $p(\textbf{w}|\textbf{t})=\eta (\textbf{w}|\textbf{m}_N)$
#
# x -> Datos
#
# t -> Salida esperada
#
# inventa el alpha
#
# se coloca el beta
#
#
# pripor por verosimilitud es igual a posterior figura elipse con tendencia del punto tomado
# ![image 1](https://i.postimg.cc/bY590xcP/prior-por-vero-vez-0.jpg)
#
#
# El posterior obtenido en un momento cero peude utilziarse como prior para una siguiente iteración sobre la verosimilitud y en ocasiones peude formar una mejor tendencia del sistema
#
# Primera vez
# ![image 2](https://i.postimg.cc/kG2F34SL/prior-por-vero-vez-1.jpg)
#
# Segunda vez
# ![image 3](https://i.postimg.cc/vTC7QsLT/prior-por-vero-vez-3.jpg)
#
# Se esta buscando ver la tendencia del comprotmaiento de los datos ya que el modelo tiene variables aleatorias, en este caso este tiene una función de probabilidad ya que no es puntual $p(\textbf{w}|t)$

# %% [markdown]
# # Maximizar A Posteiror (MAP)
# * La regularización se puede ver como estimación Maxima A posteriore (MAP)
# * EL logaritmo del posteiror es una función
#
# w t w es de la regularación
#
# El tanto a regularizar es a razón del alpha y betha
#
# * Equivalente a la regularización si $\lambda = \alpha / \beta$
#
# # Distribución predictiva
# * **Objetivo:** Hacer predicciones de t (puntuales de algunos valores nuevos) a partir de los nuevos avalores **x** (nuevas entradas)
# * Denotemos ese nuevo valor de entrada como $\textbf{x}_{*}$ y la predicción
#
# $\beta$ -> incertidumbre
#
# Probabilidad de obtener una salida nueva con un cierto valor dado un wt y con esa entrada nueva
# $P(t_{*}|w^{\top}\varphi (\mathbb{X}_{K}), \beta^{-1})$ $p(w|t, \alpha, \beta, \mathbb{X})$
#
# La distribución prectivida
#
# $p(t_{*}|\textbf{w}, \beta , \textbf{x}_{*})$ ->
#
# La certitumbre dle esquema bayesiano depende del beta y de la incertidumbre del conjunto de los datos
#
# $\beta^{1}+\phi(\textbf{x}_{*}^{\top) = \sigma _{*}^{2}$
#
# $M_N$ -> La media del posterior
#
#
# A medida que hay datos la distribución predictiva muestra un grado de dispersión, con este se logra establecer la probabilidad de los datos.
#
# ![iamge 5](https://i.postimg.cc/XvCdjh1D/distribucion-predictiva.jpg)
#
#  La diferencia que tiene netre maxima verosimilitud y este que es el esquema bayesiano logaa apreciar los datos atipicos. La regresión solo funciona con datos continuos
#
#  ## Otra representación
#  ![image 6](https://i.postimg.cc/3JkRQGct/otra-reprsentacion-de-predictiva.jpg)
#
#  Los coeficientes del sistema indican la relevancia que tienen las variables en el modelo, las variables provienen de las caracteristicas que se le de a los datos de **x** como el grado de las caracteriticas polinomiale so el número de centroides
