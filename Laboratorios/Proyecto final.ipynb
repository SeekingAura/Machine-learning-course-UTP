# %% [markdown]
# # Proyecto

# %%
from scipy.io import loadmat
# Load datasets
data_reg=loadmat("Carlos Arturo Moreno Tabares - regression.mat")
data_clf=loadmat("Carlos Arturo Moreno Tabares - classification.mat")

print("Cargada")
# Out:
# Cargada

# %%
import random
import numpy as np
import joblib
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
import pandas as pd

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

print("  REGRESSION DATA  ".center(100, "%"))

# Regression
X=data_reg["X"]
y=data_reg["y"][0]

# Show shapes
print("  Shapes  ".center(50, "*"))
print("X Shape {}".format(X.shape))
print("y shape {}".format(y.shape))

print("  End of Shapes  ".center(50, "*"))

# Prepare grid settings
print("  Grid settings  ".center(50, "#"))
#kernel=('rbf', 'linear', 'poly', 'sigmoid')
kernel=('rbf',)
C=np.linspace(0.01, 1, 2)
gamma=('auto', 'scale')
# gamma=np.logspace(-5, 5, 2)
# degree=(2, 3, 4, 5, 6)
max_iter=(10000,)
cache_size=(1000,)
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# "accuracy"
# "balanced_accuracy"
# ""
scoring="r2"
parameters = {'kernel':kernel, 'C':C, "gamma":gamma, "max_iter":max_iter, 'cache_size':cache_size}#, "degree":degree}

print("parameters {}".format(parameters))
print("scoring {}".format(scoring))

print("  End of Grid settings  ".center(50, "#"))

# Prepare grid settings
print("  Make Regressions with grid object  ".center(50, "*"))

mdl_reg = SVR()

mdl_reg = GridSearchCV(mdl_reg, parameters, 
                   n_jobs=-1, scoring=scoring)

mdl_reg.fit(X, y)

print("  End of Make Regressions with grid object  ".center(50, "*"))

# Save machine and save sumary
print("  Save 'best' machine for this run  ".center(50, "#"))

print("Best score: {}".format(mdl_reg.best_score_))

print("Best params \n C={} \n gamma={} \n kernel={} ".format(mdl_reg.best_params_["C"], 
                                                                    mdl_reg.best_params_["gamma"], 
                                                                    mdl_reg.best_params_["kernel"])
     )

# Maquina con el mejor rank
# clf.best_estimator_
joblib.dump(mdl_reg, '1088029924_reg.sav') # mlp: es la clase con el modelo entrenado, por ustedes. 

df=pd.DataFrame(mdl_reg.cv_results_)
df.to_csv('1088029924_reg.csv')
# df.head(-1)

print("  End of Save 'best' machine for this run  ".center(50, "#"))


print("  END OF REGRESSION DATA  ".center(100, "%"))
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  REGRESSION DATA  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************  Shapes  ********************
# X Shape (10603, 10)
# y shape (10603,)
# ****************  End of Shapes  *****************
# ################  Grid settings  #################
# parameters {'kernel': ('rbf',), 'C': array([0.01, 1.  ]), 'gamma': ('auto', 'scale'), 'max_iter': (10000,), 'cache_size': (1000,)}
# scoring r2
# #############  End of Grid settings  #############
# ******  Make Regressions with grid object  *******
# ***  End of Make Regressions with grid object  ***
# #######  Save 'best' machine for this run  #######
# Best score: 0.09780969922148382
# Best params
#  C=1.0
#  gamma=auto
#  kernel=rbf
# ###  End of Save 'best' machine for this run  ####
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  END OF REGRESSION DATA  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
import random
import numpy as np
import joblib
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
import pandas as pd

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

print("  CLASIFICATION DATA  ".center(100, "%"))
# Classification
X=data_clf["X"]
y=data_clf["y"][0]

# Show shapes
print("  Shapes  ".center(50, "*"))
print("X Shape {}".format(X.shape))
print("y shape {}".format(y.shape))

print("  End of Shapes  ".center(50, "*"))

# Prepare grid settings
print("  Grid settings  ".center(50, "#"))
# kernel=('rbf', 'linear', 'poly', 'sigmoid')
kernel=('rbf',)
C=np.linspace(0.01, 1, 2)
gamma=('auto', 'scale')
#gamma=np.logspace(-1, 1, 2)
# degree=(2, 3, 4, 5, 6)
max_iter=(100,)
cache_size=(1000,)
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# "accuracy"
# "balanced_accuracy"
# ""
scoring="accuracy"
parameters = {'kernel':kernel, 'C':C, "gamma":gamma, 'max_iter':max_iter, 'cache_size':cache_size} #, 'degree':degree}

print("parameters {}".format(parameters))
print("scoring {}".format(scoring))

print("  End of Grid settings  ".center(50, "#"))

# Prepare grid settings
print("  Make Classifications with grid object  ".center(50, "*"))

mdl_clf = SVC()

mdl_clf = GridSearchCV(mdl_clf, parameters, 
                   n_jobs=-1, scoring=scoring)

mdl_clf.fit(X, y)

print("  End of Make Regressions with grid object  ".center(50, "*"))

# Save machine and save sumary
print("  Save 'best' machine for this run  ".center(50, "#"))

print("Best score: {}".format(mdl_clf.best_score_))

print("Best params \n C={} \n gamma={} \n kernel={} ".format(mdl_clf.best_params_["C"], 
                                                                    mdl_clf.best_params_["gamma"], 
                                                                    mdl_clf.best_params_["kernel"])
     )

# Maquina con el mejor rank
# clf.best_estimator_
joblib.dump(mdl_clf, '1088029924_clf.sav') # mlp: es la clase con el modelo entrenado, por ustedes. 

df=pd.DataFrame(mdl_clf.cv_results_)
df.to_csv('1088029924_clf.csv')
# df.head(-1)

print("  End of Save 'best' machine for this run  ".center(50, "#"))


print("  END OF CLASSIFICATION DATA  ".center(100, "%"))
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  CLASIFICATION DATA  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************  Shapes  ********************
# X Shape (84296, 14)
# y shape (84296,)
# ****************  End of Shapes  *****************
# ################  Grid settings  #################
# parameters {'kernel': ('rbf',), 'C': array([0.01, 1.  ]), 'gamma': ('auto', 'scale'), 'max_iter': (100,), 'cache_size': (1000,)}
# scoring accuracy
# #############  End of Grid settings  #############
# ****  Make Classifications with grid object  *****
# ***  End of Make Regressions with grid object  ***
# #######  Save 'best' machine for this run  #######
# Best score: 0.07817701799525292
# Best params
#  C=1.0
#  gamma=scale
#  kernel=rbf
# ###  End of Save 'best' machine for this run  ####
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  END OF CLASSIFICATION DATA  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# c:\python38\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
