# %% [markdown]
# # Proyecto

# %%
from scipy.io import loadmat
# Load datasets
data_reg=loadmat("Carlos Arturo Moreno Tabares - regression.mat")
data_clf=loadmat("Carlos Arturo Moreno Tabares - classification.mat")

print("Cargada")
# Out:
# Cargada

# %%
import random
import numpy as np
import joblib
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
import pandas as pd




print("  REGRESSION DATA  ".center(100, "%"))

# Regression
X=data_reg["X"]
y=data_reg["y"][0]

# Show shapes
print("  Shapes  ".center(50, "*"))
print("X Shape {}".format(X.shape))
print("y shape {}".format(y.shape))

print("  End of Shapes  ".center(50, "*"))

# Prepare grid settings
print("  Grid settings  ".center(50, "#"))
kernel=('rbf',)
C=np.linspace(0.01, 1, 3)
gamma=np.logspace(-5, 5, 5)
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# "accuracy"
# "balanced_accuracy"
# ""
scoring="accuracy"
parameters = {'kernel':kernel, 'C':C, "gamma":gamma}

print("parameters {}".format(parameters))
print("scoring {}".format(scoring))

print("  End of Grid settings  ".center(50, "#"))

# Prepare grid settings
print("  Make Regressions with grid object  ".center(50, "*"))

mdl_reg = SVR()

mdl_reg = GridSearchCV(mdl_reg, parameters, 
                   n_jobs=-1, scoring=scoring)

mdl_reg.fit(X, y)

print("  End of Make Regressions with grid object  ".center(50, "*"))

# Save machine and save sumary
print("  Save 'best' machine for this run  ".center(50, "#"))

print("Best score: {}".format(mdl_reg.best_score_))

print("Best params \n C={} \n gamma={} \n kernel={} ".format(mdl_reg.best_params_["C"], 
                                                                    mdl_reg.best_params_["gamma"], 
                                                                    mdl_reg.best_params_["kernel"])
     )

# Maquina con el mejor rank
# clf.best_estimator_
joblib.dump(mdl_reg, '1088029924_reg.sav') # mlp: es la clase con el modelo entrenado, por ustedes. 

df=pd.DataFrame(mdl_reg.cv_results_)
df.to_csv('1088029924_reg.csv')
# df.head(-1)

print("  End of Save 'best' machine for this run  ".center(50, "#"))


print("  END OF REGRESSION DATA  ".center(100, "%"))



print("  CLASIFICATION DATA  ".center(100, "%"))
# Classification
X=data_clf["X"]
y=data_clf["y"][0]

# Show shapes
print("  Shapes  ".center(50, "*"))
print("X Shape {}".format(X.shape))
print("y shape {}".format(y.shape))

print("  End of Shapes  ".center(50, "*"))

# Prepare grid settings
print("  Grid settings  ".center(50, "#"))
kernel=('rbf', 'linear')
C=np.linspace(0.01, 1, 3)
gamma=np.logspace(-5, 5, 5)
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# "accuracy"
# "balanced_accuracy"
# ""
scoring="accuracy"
parameters = {'kernel':kernel, 'C':C, "gamma":gamma}

print("parameters {}".format(parameters))
print("scoring {}".format(scoring))

print("  End of Grid settings  ".center(50, "#"))

# Prepare grid settings
print("  Make Regressions with grid object  ".center(50, "*"))

mdl_clf = SVC()

mdl_clf = GridSearchCV(mdl_clf, parameters, 
                   n_jobs=-1, scoring=scoring)

mdl_clf.fit(X, y)

print("  End of Make Regressions with grid object  ".center(50, "*"))

# Save machine and save sumary
print("  Save 'best' machine for this run  ".center(50, "#"))

print("Best score: {}".format(mdl_clf.best_score_))

print("Best params \n C={} \n gamma={} \n kernel={} ".format(mdl_clf.best_params_["C"], 
                                                                    mdl_clf.best_params_["gamma"], 
                                                                    mdl_clf.best_params_["kernel"])
     )

# Maquina con el mejor rank
# clf.best_estimator_
joblib.dump(mdl_clf, '1088029924_clf.sav') # mlp: es la clase con el modelo entrenado, por ustedes. 

df=pd.DataFrame(mdl_clf.cv_results_)
df.to_csv('1088029924_clf.csv')
# df.head(-1)

print("  End of Save 'best' machine for this run  ".center(50, "#"))


print("  END OF CLASSIFICATION DATA  ".center(100, "%"))
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  REGRESSION DATA  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************  Shapes  ********************
# X Shape (10603, 10)
# y shape (10603,)
# ****************  End of Shapes  *****************
# ################  Grid settings  #################
# parameters {'kernel': ('rbf',), 'C': array([0.01 , 0.505, 1.   ]), 'gamma': array([1.00000000e-05, 3.16227766e-03, 1.00000000e+00, 3.16227766e+02,
#        1.00000000e+05])}
# scoring accuracy
# #############  End of Grid settings  #############
# ******  Make Regressions with grid object  *******
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\program files\python38\lib\site-packages\joblib\externals\loky\process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "c:\program files\python38\lib\site-packages\joblib\externals\loky\process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "c:\program files\python38\lib\site-packages\joblib\_parallel_backends.py", line 608, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\program files\python38\lib\site-packages\joblib\parallel.py", line 255, in __call__
#     return [func(*args, **kwargs)
#   File "c:\program files\python38\lib\site-packages\joblib\parallel.py", line 255, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\program files\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 544, in _fit_and_score
#     test_scores = _score(estimator, X_test, y_test, scorer)
#   File "c:\program files\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 591, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\program files\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "c:\program files\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 211, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py", line 185, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "c:\program files\python38\lib\site-packages\sklearn\metrics\_classification.py", line 89, in _check_targets
#     raise ValueError("Classification metrics can't handle a mix of {0} "
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d2d9a0feb8cf> in <module>
#      48                    n_jobs=-1, scoring=scoring)
#      49
# ---> 50 mdl_reg.fit(X, y)
#      51
#      52 print("  End of Make Regressions with grid object  ".center(50, "*"))
#
# c:\program files\python38\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# c:\program files\python38\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# c:\program files\python38\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     680                               n_splits, n_candidates, n_candidates * n_splits))
#     681
# --> 682                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     683                                                        X, y,
#     684                                                        train=train, test=test,
#
# c:\program files\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# c:\program files\python38\lib\site-packages\joblib\parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# c:\program files\python38\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     560         AsyncResults.get from multiprocessing."""
#     561         try:
# --> 562             return future.result(timeout=timeout)
#     563         except LokyTimeoutError:
#     564             raise TimeoutError()
#
# c:\program files\python38\lib\concurrent\futures\_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# c:\program files\python38\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
